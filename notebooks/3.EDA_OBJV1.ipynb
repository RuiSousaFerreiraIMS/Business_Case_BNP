# %% [markdown]
# # OBJECTIVE 1

# %% [markdown]
# ## EDA – Early Settlement Analysis (IS_SAN)
#
# **Objective:**
#
# Identify structural differences between:
# - Clients who settle early (IS_SAN = 1)
# - Clients who go to maturity (IS_SAN = 0)
#
# Goal: detect financial, behavioral and demographic patterns that characterize early settlers.

# %%
import importlib
import sys, os

# Ensure project root is on path
sys.path.insert(0, os.path.abspath(".."))

import src.code.data_preparation as dp
import src.code.data_functions as dfun
import src.code.io_utils as io

importlib.reload(dp)
importlib.reload(dfun)
importlib.reload(io)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", palette="muted")
pd.set_option("display.max_columns", 60)
pd.set_option("display.float_format", "{:.3f}".format)



print("Setup complete.")
# Out:
# Setup complete.

# %%
abt_data = io.load("../data/prepared/abt_first_objective.parquet")
abt_data.head(3)
# Out:
# [LOAD] ../data/prepared/abt_first_objective.parquet | shape: (428865, 107)
#                                              CONTRIB  BICONTRATO   OBS_DATE  \
# 0  0000e359b15a80ba12c7f60c0fe06ffc68621c87f13a4f...       0.000 2024-01-31
# 1  000607d1adce7aa9ac87274d1a2ffa84e240188de0872f...       0.000 2024-01-31
# 2  00090305c0bcef4a212c328717f904808c0ae3b520eff9...       0.000 2024-01-31
#
#    DURDEG  RANGPRO  RANGCLI   MTFINO    MTFIN  MENSALIDADE  MENSALIDADE_CORR  \
# 0  72.000   34.000   34.000 2500.000 2500.000       56.018            56.018
# 1  60.000   60.000   60.000 5000.000 5000.000      128.984           128.984
# 2  24.000   23.000   23.000 2000.000 2000.000      110.643           110.643
#
#     CRD  SREC    RN    RD  RISK  RISKA   AGFIN   RESSO    CSP   PTT  NBENF  \
# 0 0.000 0.000 1.000 1.000     1  0.000 120.000 838.186 91.000  2855  0.000
# 1 0.000 0.000 0.000 0.000     0  0.000 118.000 912.411 60.000  9680  2.000
# ...

# %% [markdown]
# ### 1. Target Distribution

# %%
abt_data["IS_SAN"].value_counts()
# Out:
# IS_SAN
# 1    275931
# 0    152934
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Financial Profile Comparison by IS_SAN

# %% [markdown]
# ### 4. Risk and Behavioural Indicators

# %%
"""
RISK / RISKA

crc_total_overdue

COUNT_TOTAL

ALLBD_N_events__N

ALLBD_mean_active_resso__N

objetivo: São clientes financeiramente mais experientes?
São menos arriscados?
"""
# Out:
# '\nRISK / RISKA\n\ncrc_total_overdue\n\nCOUNT_TOTAL\n\nALLBD_N_events__N\n\nALLBD_mean_active_resso__N\n'

# %% [markdown]
# ### 5. Loan Structure Characteristics

# %%
"""
DURDEG

loan_age_months (se não houver leakage)

TYPEPROD_CL

Produto SAN vs SOL

Pergunta:
"""

#objetico: Early settlement acontece mais em contratos longos?

# %% [markdown]
# ### 6. Sociodemographic Differences

# %%
"""
sdem_age

SITFAM

HABITAT
"""

# %% [markdown]
# ### 7. Multivariate Interaction Insights

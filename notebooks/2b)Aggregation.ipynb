# %% [markdown]
# # 4. Aggregation
#
# > **Content moved to [2.Data_Preparation.ipynb](2.Data_Preparation.ipynb), sections 2.6 and 2.7.**
# >
# > - **2.6** — Aggregate each dataset to customer level (BDOSS, CRC, CREDSCORE, FAMA)
# > - **2.7** — Merge all aggregated datasets → ABT (one row per customer)
